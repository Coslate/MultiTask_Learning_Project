# %% [markdown]
# # Welcome to the HydraNet Home Robot Workshop 🐸🐸🐸
#
# In this workshop, you're going to learn how to train a Neural Network that does **real-time semantic segmentation and monocular depth prediction**.
#
# ![](https://d3i71xaburhd42.cloudfront.net/435d4b5c30f10753d277848a17baddebd98d3c31/2-Figure1-1.png)
#
# The Model is [a Multi-Task Learning algorithm designed by Vladimir Nekrasov](https://arxiv.org/pdf/1809.04766.pdf). The entire work is based on the **DenseTorch Library**, that you can find and use [here](https://github.com/DrSleep/DenseTorch). <p>
#
# **A note —** This notebook is adapting the Library with express authorization from the author for educational purpose.
#
# ## Home Robot 🤖
# * In the previous workshop of the course, you learned how to design the model shown above, and to run it on the KITTI Dataset using pretrained weights. The **KITTI Dataset only has 200 examples of segmentation**. Therefore, the authors used a technique called Knowledge Distillation and finetuned using the Cityscape dataset.<p>
#
# * 👉 In our case, we'll use another dataset called the [NYUDv2 Dataset](https://cs.nyu.edu/~silberman/datasets/nyu_depth_v2.html). **It contains 1449 annotated images for depth and segmentation**, which makes our life much simpler. —— Since this is an indoor dataset, we'll turn this project into a Home Robot Workshop!

# %% [markdown]
# #1 — Imports
#
# We're going to import:
# *   The **Data from our previous notebook** (trained model, cmaps, ...)
# *   The **NYUD Dataset**, along with helper files, ground truth examples, and train/test split files

# %%
# !wget https://hydranets-data.s3.eu-west-3.amazonaws.com/hydranets-data-2.zip && unzip -q hydranets-data-2.zip && mv hydranets-data-2/* . && rm hydranets-data-2.zip && rm -rf hydranets-data-2
# Out:
# --2025-02-07 22:42:21--  https://hydranets-data.s3.eu-west-3.amazonaws.com/hydranets-data-2.zip
# Resolving hydranets-data.s3.eu-west-3.amazonaws.com (hydranets-data.s3.eu-west-3.amazonaws.com)... 3.5.224.142, 3.5.206.27, 3.5.205.183, ...
# Connecting to hydranets-data.s3.eu-west-3.amazonaws.com (hydranets-data.s3.eu-west-3.amazonaws.com)|3.5.224.142|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 812068227 (774M) [application/zip]
# Saving to: ‘hydranets-data-2.zip’
#
# hydranets-data-2.zi 100%[===================>] 774.45M  14.1MB/s    in 43s
#
# 2025-02-07 22:43:02 (18.1 MB/s) - ‘hydranets-data-2.zip’ saved [812068227/812068227]

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from PIL import Image
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F

# %% [markdown]
# # 1 — Dataset
# Let's begin with importing our data, and visualizing it.

# %% [markdown]
# ## Load and Visualize the Dataset

# %%
import glob

depth = sorted(glob.glob("./nyud/depth/*.png"))#TODO: Load the Path
seg = sorted(glob.glob("./nyud/masks/*.png"))#TODO: Load the Path
images = sorted(glob.glob("./nyud/rgb/*.png"))#TODO: Load the Path

# %%
depth
# Out:
# ['./nyud/depth/000001.png',
#  './nyud/depth/000002.png',
#  './nyud/depth/000003.png',
#  './nyud/depth/000004.png',
#  './nyud/depth/000005.png',
#  './nyud/depth/000006.png',
#  './nyud/depth/000007.png',
#  './nyud/depth/000008.png',
#  './nyud/depth/000009.png',
#  './nyud/depth/000010.png',
#  './nyud/depth/000011.png',
#  './nyud/depth/000012.png',
#  './nyud/depth/000013.png',
#  './nyud/depth/000014.png',
#  './nyud/depth/000015.png',
#  './nyud/depth/000016.png',
#  './nyud/depth/000017.png',
#  './nyud/depth/000018.png',
#  './nyud/depth/000019.png',
#  './nyud/depth/000020.png',
#  './nyud/depth/000021.png',
#  './nyud/depth/000022.png',
#  './nyud/depth/000023.png',
#  './nyud/depth/000024.png',
#  './nyud/depth/000025.png',
#  './nyud/depth/000026.png',
#  './nyud/depth/000027.png',
#  './nyud/depth/000028.png',
#  './nyud/depth/000029.png',
#  './nyud/depth/000030.png',
#  './nyud/depth/000031.png',
#  './nyud/depth/000032.png',
#  './nyud/depth/000033.png',
#  './nyud/depth/000034.png',
#  './nyud/depth/000035.png',
#  './nyud/depth/000036.png',
#  './nyud/depth/000037.png',
#  './nyud/depth/000038.png',
#  './nyud/depth/000039.png',
#  './nyud/depth/000040.png',
#  './nyud/depth/000041.png',
#  './nyud/depth/000042.png',
#  './nyud/depth/000043.png',
#  './nyud/depth/000044.png',
#  './nyud/depth/000045.png',
#  './nyud/depth/000046.png',
#  './nyud/depth/000047.png',
#  './nyud/depth/000048.png',
#  './nyud/depth/000049.png',
#  './nyud/depth/000050.png',
#  './nyud/depth/000051.png',
#  './nyud/depth/000052.png',
#  './nyud/depth/000053.png',
#  './nyud/depth/000054.png',
#  './nyud/depth/000055.png',
#  './nyud/depth/000056.png',
#  './nyud/depth/000057.png',
#  './nyud/depth/000058.png',
#  './nyud/depth/000059.png',
#  './nyud/depth/000060.png',
#  './nyud/depth/000061.png',
#  './nyud/depth/000062.png',
#  './nyud/depth/000063.png',
#  './nyud/depth/000064.png',
#  './nyud/depth/000065.png',
#  './nyud/depth/000066.png',
#  './nyud/depth/000067.png',
#  './nyud/depth/000068.png',
#  './nyud/depth/000069.png',
#  './nyud/depth/000070.png',
#  './nyud/depth/000071.png',
#  './nyud/depth/000072.png',
#  './nyud/depth/000073.png',
#  './nyud/depth/000074.png',
#  './nyud/depth/000075.png',
#  './nyud/depth/000076.png',
#  './nyud/depth/000077.png',
#  './nyud/depth/000078.png',
#  './nyud/depth/000079.png',
#  './nyud/depth/000080.png',
#  './nyud/depth/000081.png',
#  './nyud/depth/000082.png',
#  './nyud/depth/000083.png',
#  './nyud/depth/000084.png',
#  './nyud/depth/000085.png',
#  './nyud/depth/000086.png',
#  './nyud/depth/000087.png',
#  './nyud/depth/000088.png',
#  './nyud/depth/000089.png',
#  './nyud/depth/000090.png',
#  './nyud/depth/000091.png',
#  './nyud/depth/000092.png',
#  './nyud/depth/000093.png',
#  './nyud/depth/000094.png',
#  './nyud/depth/000095.png',
#  './nyud/depth/000096.png',
#  './nyud/depth/000097.png',
#  './nyud/depth/000098.png',
#  './nyud/depth/000099.png',
#  './nyud/depth/000100.png',
#  './nyud/depth/000101.png',
#  './nyud/depth/000102.png',
#  './nyud/depth/000103.png',
#  './nyud/depth/000104.png',
#  './nyud/depth/000105.png',
#  './nyud/depth/000106.png',
#  './nyud/depth/000107.png',
#  './nyud/depth/000108.png',
#  './nyud/depth/000109.png',
#  './nyud/depth/000110.png',
#  './nyud/depth/000111.png',
#  './nyud/depth/000112.png',
#  './nyud/depth/000113.png',
#  './nyud/depth/000114.png',
#  './nyud/depth/000115.png',
#  './nyud/depth/000116.png',
#  './nyud/depth/000117.png',
#  './nyud/depth/000118.png',
#  './nyud/depth/000119.png',
#  './nyud/depth/000120.png',
#  './nyud/depth/000121.png',
#  './nyud/depth/000122.png',
#  './nyud/depth/000123.png',
#  './nyud/depth/000124.png',
#  './nyud/depth/000125.png',
#  './nyud/depth/000126.png',
#  './nyud/depth/000127.png',
#  './nyud/depth/000128.png',
#  './nyud/depth/000129.png',
#  './nyud/depth/000130.png',
#  './nyud/depth/000131.png',
#  './nyud/depth/000132.png',
#  './nyud/depth/000133.png',
#  './nyud/depth/000134.png',
#  './nyud/depth/000135.png',
#  './nyud/depth/000136.png',
#  './nyud/depth/000137.png',
#  './nyud/depth/000138.png',
#  './nyud/depth/000139.png',
#  './nyud/depth/000140.png',
#  './nyud/depth/000141.png',
#  './nyud/depth/000142.png',
#  './nyud/depth/000143.png',
#  './nyud/depth/000144.png',
#  './nyud/depth/000145.png',
#  './nyud/depth/000146.png',
#  './nyud/depth/000147.png',
#  './nyud/depth/000148.png',
#  './nyud/depth/000149.png',
#  './nyud/depth/000150.png',
#  './nyud/depth/000151.png',
#  './nyud/depth/000152.png',
#  './nyud/depth/000153.png',
#  './nyud/depth/000154.png',
#  './nyud/depth/000155.png',
#  './nyud/depth/000156.png',
#  './nyud/depth/000157.png',
#  './nyud/depth/000158.png',
#  './nyud/depth/000159.png',
#  './nyud/depth/000160.png',
#  './nyud/depth/000161.png',
#  './nyud/depth/000162.png',
#  './nyud/depth/000163.png',
#  './nyud/depth/000164.png',
#  './nyud/depth/000165.png',
#  './nyud/depth/000166.png',
#  './nyud/depth/000167.png',
#  './nyud/depth/000168.png',
#  './nyud/depth/000169.png',
#  './nyud/depth/000170.png',
#  './nyud/depth/000171.png',
#  './nyud/depth/000172.png',
#  './nyud/depth/000173.png',
#  './nyud/depth/000174.png',
#  './nyud/depth/000175.png',
#  './nyud/depth/000176.png',
#  './nyud/depth/000177.png',
#  './nyud/depth/000178.png',
#  './nyud/depth/000179.png',
#  './nyud/depth/000180.png',
#  './nyud/depth/000181.png',
#  './nyud/depth/000182.png',
#  './nyud/depth/000183.png',
#  './nyud/depth/000184.png',
#  './nyud/depth/000185.png',
#  './nyud/depth/000186.png',
#  './nyud/depth/000187.png',
#  './nyud/depth/000188.png',
#  './nyud/depth/000189.png',
#  './nyud/depth/000190.png',
#  './nyud/depth/000191.png',
#  './nyud/depth/000192.png',
#  './nyud/depth/000193.png',
#  './nyud/depth/000194.png',
#  './nyud/depth/000195.png',
#  './nyud/depth/000196.png',
#  './nyud/depth/000197.png',
#  './nyud/depth/000198.png',
#  './nyud/depth/000199.png',
#  './nyud/depth/000200.png',
#  './nyud/depth/000201.png',
#  './nyud/depth/000202.png',
#  './nyud/depth/000203.png',
#  './nyud/depth/000204.png',
#  './nyud/depth/000205.png',
#  './nyud/depth/000206.png',
#  './nyud/depth/000207.png',
#  './nyud/depth/000208.png',
#  './nyud/depth/000209.png',
#  './nyud/depth/000210.png',
#  './nyud/depth/000211.png',
#  './nyud/depth/000212.png',
#  './nyud/depth/000213.png',
#  './nyud/depth/000214.png',
#  './nyud/depth/000215.png',
#  './nyud/depth/000216.png',
#  './nyud/depth/000217.png',
#  './nyud/depth/000218.png',
#  './nyud/depth/000219.png',
#  './nyud/depth/000220.png',
#  './nyud/depth/000221.png',
#  './nyud/depth/000222.png',
#  './nyud/depth/000223.png',
#  './nyud/depth/000224.png',
#  './nyud/depth/000225.png',
#  './nyud/depth/000226.png',
#  './nyud/depth/000227.png',
#  './nyud/depth/000228.png',
#  './nyud/depth/000229.png',
#  './nyud/depth/000230.png',
#  './nyud/depth/000231.png',
#  './nyud/depth/000232.png',
#  './nyud/depth/000233.png',
#  './nyud/depth/000234.png',
#  './nyud/depth/000235.png',
#  './nyud/depth/000236.png',
#  './nyud/depth/000237.png',
#  './nyud/depth/000238.png',
#  './nyud/depth/000239.png',
#  './nyud/depth/000240.png',
#  './nyud/depth/000241.png',
#  './nyud/depth/000242.png',
#  './nyud/depth/000243.png',
#  './nyud/depth/000244.png',
#  './nyud/depth/000245.png',
#  './nyud/depth/000246.png',
#  './nyud/depth/000247.png',
#  './nyud/depth/000248.png',
#  './nyud/depth/000249.png',
#  './nyud/depth/000250.png',
#  './nyud/depth/000251.png',
#  './nyud/depth/000252.png',
#  './nyud/depth/000253.png',
#  './nyud/depth/000254.png',
#  './nyud/depth/000255.png',
#  './nyud/depth/000256.png',
#  './nyud/depth/000257.png',
#  './nyud/depth/000258.png',
#  './nyud/depth/000259.png',
#  './nyud/depth/000260.png',
#  './nyud/depth/000261.png',
#  './nyud/depth/000262.png',
#  './nyud/depth/000263.png',
#  './nyud/depth/000264.png',
#  './nyud/depth/000265.png',
#  './nyud/depth/000266.png',
#  './nyud/depth/000267.png',
#  './nyud/depth/000268.png',
#  './nyud/depth/000269.png',
#  './nyud/depth/000270.png',
#  './nyud/depth/000271.png',
#  './nyud/depth/000272.png',
#  './nyud/depth/000273.png',
#  './nyud/depth/000274.png',
#  './nyud/depth/000275.png',
#  './nyud/depth/000276.png',
#  './nyud/depth/000277.png',
#  './nyud/depth/000278.png',
#  './nyud/depth/000279.png',
#  './nyud/depth/000280.png',
#  './nyud/depth/000281.png',
#  './nyud/depth/000282.png',
#  './nyud/depth/000283.png',
#  './nyud/depth/000284.png',
#  './nyud/depth/000285.png',
#  './nyud/depth/000286.png',
#  './nyud/depth/000287.png',
#  './nyud/depth/000288.png',
#  './nyud/depth/000289.png',
#  './nyud/depth/000290.png',
#  './nyud/depth/000291.png',
#  './nyud/depth/000292.png',
#  './nyud/depth/000293.png',
#  './nyud/depth/000294.png',
#  './nyud/depth/000295.png',
#  './nyud/depth/000296.png',
#  './nyud/depth/000297.png',
#  './nyud/depth/000298.png',
#  './nyud/depth/000299.png',
#  './nyud/depth/000300.png',
#  './nyud/depth/000301.png',
#  './nyud/depth/000302.png',
#  './nyud/depth/000303.png',
#  './nyud/depth/000304.png',
#  './nyud/depth/000305.png',
#  './nyud/depth/000306.png',
#  './nyud/depth/000307.png',
#  './nyud/depth/000308.png',
#  './nyud/depth/000309.png',
#  './nyud/depth/000310.png',
#  './nyud/depth/000311.png',
#  './nyud/depth/000312.png',
#  './nyud/depth/000313.png',
#  './nyud/depth/000314.png',
#  './nyud/depth/000315.png',
#  './nyud/depth/000316.png',
#  './nyud/depth/000317.png',
#  './nyud/depth/000318.png',
#  './nyud/depth/000319.png',
#  './nyud/depth/000320.png',
#  './nyud/depth/000321.png',
#  './nyud/depth/000322.png',
#  './nyud/depth/000323.png',
#  './nyud/depth/000324.png',
#  './nyud/depth/000325.png',
#  './nyud/depth/000326.png',
#  './nyud/depth/000327.png',
#  './nyud/depth/000328.png',
#  './nyud/depth/000329.png',
#  './nyud/depth/000330.png',
#  './nyud/depth/000331.png',
#  './nyud/depth/000332.png',
#  './nyud/depth/000333.png',
#  './nyud/depth/000334.png',
#  './nyud/depth/000335.png',
#  './nyud/depth/000336.png',
#  './nyud/depth/000337.png',
#  './nyud/depth/000338.png',
#  './nyud/depth/000339.png',
#  './nyud/depth/000340.png',
#  './nyud/depth/000341.png',
#  './nyud/depth/000342.png',
#  './nyud/depth/000343.png',
#  './nyud/depth/000344.png',
#  './nyud/depth/000345.png',
#  './nyud/depth/000346.png',
#  './nyud/depth/000347.png',
#  './nyud/depth/000348.png',
#  './nyud/depth/000349.png',
#  './nyud/depth/000350.png',
#  './nyud/depth/000351.png',
#  './nyud/depth/000352.png',
#  './nyud/depth/000353.png',
#  './nyud/depth/000354.png',
#  './nyud/depth/000355.png',
#  './nyud/depth/000356.png',
#  './nyud/depth/000357.png',
#  './nyud/depth/000358.png',
#  './nyud/depth/000359.png',
#  './nyud/depth/000360.png',
#  './nyud/depth/000361.png',
#  './nyud/depth/000362.png',
#  './nyud/depth/000363.png',
#  './nyud/depth/000364.png',
#  './nyud/depth/000365.png',
#  './nyud/depth/000366.png',
#  './nyud/depth/000367.png',
#  './nyud/depth/000368.png',
#  './nyud/depth/000369.png',
#  './nyud/depth/000370.png',
#  './nyud/depth/000371.png',
#  './nyud/depth/000372.png',
#  './nyud/depth/000373.png',
#  './nyud/depth/000374.png',
#  './nyud/depth/000375.png',
#  './nyud/depth/000376.png',
#  './nyud/depth/000377.png',
#  './nyud/depth/000378.png',
#  './nyud/depth/000379.png',
#  './nyud/depth/000380.png',
#  './nyud/depth/000381.png',
#  './nyud/depth/000382.png',
#  './nyud/depth/000383.png',
#  './nyud/depth/000384.png',
#  './nyud/depth/000385.png',
#  './nyud/depth/000386.png',
#  './nyud/depth/000387.png',
#  './nyud/depth/000388.png',
#  './nyud/depth/000389.png',
#  './nyud/depth/000390.png',
#  './nyud/depth/000391.png',
#  './nyud/depth/000392.png',
#  './nyud/depth/000393.png',
#  './nyud/depth/000394.png',
#  './nyud/depth/000395.png',
#  './nyud/depth/000396.png',
#  './nyud/depth/000397.png',
#  './nyud/depth/000398.png',
#  './nyud/depth/000399.png',
#  './nyud/depth/000400.png',
#  './nyud/depth/000401.png',
#  './nyud/depth/000402.png',
#  './nyud/depth/000403.png',
#  './nyud/depth/000404.png',
#  './nyud/depth/000405.png',
#  './nyud/depth/000406.png',
#  './nyud/depth/000407.png',
#  './nyud/depth/000408.png',
#  './nyud/depth/000409.png',
#  './nyud/depth/000410.png',
#  './nyud/depth/000411.png',
#  './nyud/depth/000412.png',
#  './nyud/depth/000413.png',
#  './nyud/depth/000414.png',
#  './nyud/depth/000415.png',
#  './nyud/depth/000416.png',
#  './nyud/depth/000417.png',
#  './nyud/depth/000418.png',
#  './nyud/depth/000419.png',
#  './nyud/depth/000420.png',
#  './nyud/depth/000421.png',
#  './nyud/depth/000422.png',
#  './nyud/depth/000423.png',
#  './nyud/depth/000424.png',
#  './nyud/depth/000425.png',
#  './nyud/depth/000426.png',
#  './nyud/depth/000427.png',
#  './nyud/depth/000428.png',
#  './nyud/depth/000429.png',
#  './nyud/depth/000430.png',
#  './nyud/depth/000431.png',
#  './nyud/depth/000432.png',
#  './nyud/depth/000433.png',
#  './nyud/depth/000434.png',
#  './nyud/depth/000435.png',
#  './nyud/depth/000436.png',
#  './nyud/depth/000437.png',
#  './nyud/depth/000438.png',
#  './nyud/depth/000439.png',
#  './nyud/depth/000440.png',
#  './nyud/depth/000441.png',
#  './nyud/depth/000442.png',
#  './nyud/depth/000443.png',
#  './nyud/depth/000444.png',
#  './nyud/depth/000445.png',
#  './nyud/depth/000446.png',
#  './nyud/depth/000447.png',
#  './nyud/depth/000448.png',
#  './nyud/depth/000449.png',
#  './nyud/depth/000450.png',
#  './nyud/depth/000451.png',
#  './nyud/depth/000452.png',
#  './nyud/depth/000453.png',
#  './nyud/depth/000454.png',
#  './nyud/depth/000455.png',
#  './nyud/depth/000456.png',
#  './nyud/depth/000457.png',
#  './nyud/depth/000458.png',
#  './nyud/depth/000459.png',
#  './nyud/depth/000460.png',
#  './nyud/depth/000461.png',
#  './nyud/depth/000462.png',
#  './nyud/depth/000463.png',
#  './nyud/depth/000464.png',
#  './nyud/depth/000465.png',
#  './nyud/depth/000466.png',
#  './nyud/depth/000467.png',
#  './nyud/depth/000468.png',
#  './nyud/depth/000469.png',
#  './nyud/depth/000470.png',
#  './nyud/depth/000471.png',
#  './nyud/depth/000472.png',
#  './nyud/depth/000473.png',
#  './nyud/depth/000474.png',
#  './nyud/depth/000475.png',
#  './nyud/depth/000476.png',
#  './nyud/depth/000477.png',
#  './nyud/depth/000478.png',
#  './nyud/depth/000479.png',
#  './nyud/depth/000480.png',
#  './nyud/depth/000481.png',
#  './nyud/depth/000482.png',
#  './nyud/depth/000483.png',
#  './nyud/depth/000484.png',
#  './nyud/depth/000485.png',
#  './nyud/depth/000486.png',
#  './nyud/depth/000487.png',
#  './nyud/depth/000488.png',
#  './nyud/depth/000489.png',
#  './nyud/depth/000490.png',
#  './nyud/depth/000491.png',
#  './nyud/depth/000492.png',
#  './nyud/depth/000493.png',
#  './nyud/depth/000494.png',
#  './nyud/depth/000495.png',
#  './nyud/depth/000496.png',
#  './nyud/depth/000497.png',
#  './nyud/depth/000498.png',
#  './nyud/depth/000499.png',
#  './nyud/depth/000500.png',
#  './nyud/depth/000501.png',
#  './nyud/depth/000502.png',
#  './nyud/depth/000503.png',
#  './nyud/depth/000504.png',
#  './nyud/depth/000505.png',
#  './nyud/depth/000506.png',
#  './nyud/depth/000507.png',
#  './nyud/depth/000508.png',
#  './nyud/depth/000509.png',
#  './nyud/depth/000510.png',
#  './nyud/depth/000511.png',
#  './nyud/depth/000512.png',
#  './nyud/depth/000513.png',
#  './nyud/depth/000514.png',
#  './nyud/depth/000515.png',
#  './nyud/depth/000516.png',
#  './nyud/depth/000517.png',
#  './nyud/depth/000518.png',
#  './nyud/depth/000519.png',
#  './nyud/depth/000520.png',
#  './nyud/depth/000521.png',
#  './nyud/depth/000522.png',
#  './nyud/depth/000523.png',
#  './nyud/depth/000524.png',
#  './nyud/depth/000525.png',
#  './nyud/depth/000526.png',
#  './nyud/depth/000527.png',
#  './nyud/depth/000528.png',
#  './nyud/depth/000529.png',
#  './nyud/depth/000530.png',
#  './nyud/depth/000531.png',
#  './nyud/depth/000532.png',
#  './nyud/depth/000533.png',
#  './nyud/depth/000534.png',
#  './nyud/depth/000535.png',
#  './nyud/depth/000536.png',
#  './nyud/depth/000537.png',
#  './nyud/depth/000538.png',
#  './nyud/depth/000539.png',
#  './nyud/depth/000540.png',
#  './nyud/depth/000541.png',
#  './nyud/depth/000542.png',
#  './nyud/depth/000543.png',
#  './nyud/depth/000544.png',
#  './nyud/depth/000545.png',
#  './nyud/depth/000546.png',
#  './nyud/depth/000547.png',
#  './nyud/depth/000548.png',
#  './nyud/depth/000549.png',
#  './nyud/depth/000550.png',
#  './nyud/depth/000551.png',
#  './nyud/depth/000552.png',
#  './nyud/depth/000553.png',
#  './nyud/depth/000554.png',
#  './nyud/depth/000555.png',
#  './nyud/depth/000556.png',
#  './nyud/depth/000557.png',
#  './nyud/depth/000558.png',
#  './nyud/depth/000559.png',
#  './nyud/depth/000560.png',
#  './nyud/depth/000561.png',
#  './nyud/depth/000562.png',
#  './nyud/depth/000563.png',
#  './nyud/depth/000564.png',
#  './nyud/depth/000565.png',
#  './nyud/depth/000566.png',
#  './nyud/depth/000567.png',
#  './nyud/depth/000568.png',
#  './nyud/depth/000569.png',
#  './nyud/depth/000570.png',
#  './nyud/depth/000571.png',
#  './nyud/depth/000572.png',
#  './nyud/depth/000573.png',
#  './nyud/depth/000574.png',
#  './nyud/depth/000575.png',
#  './nyud/depth/000576.png',
#  './nyud/depth/000577.png',
#  './nyud/depth/000578.png',
#  './nyud/depth/000579.png',
#  './nyud/depth/000580.png',
#  './nyud/depth/000581.png',
#  './nyud/depth/000582.png',
#  './nyud/depth/000583.png',
#  './nyud/depth/000584.png',
#  './nyud/depth/000585.png',
#  './nyud/depth/000586.png',
#  './nyud/depth/000587.png',
#  './nyud/depth/000588.png',
#  './nyud/depth/000589.png',
#  './nyud/depth/000590.png',
#  './nyud/depth/000591.png',
#  './nyud/depth/000592.png',
#  './nyud/depth/000593.png',
#  './nyud/depth/000594.png',
#  './nyud/depth/000595.png',
#  './nyud/depth/000596.png',
#  './nyud/depth/000597.png',
#  './nyud/depth/000598.png',
#  './nyud/depth/000599.png',
#  './nyud/depth/000600.png',
#  './nyud/depth/000601.png',
#  './nyud/depth/000602.png',
#  './nyud/depth/000603.png',
#  './nyud/depth/000604.png',
#  './nyud/depth/000605.png',
#  './nyud/depth/000606.png',
#  './nyud/depth/000607.png',
#  './nyud/depth/000608.png',
#  './nyud/depth/000609.png',
#  './nyud/depth/000610.png',
#  './nyud/depth/000611.png',
#  './nyud/depth/000612.png',
#  './nyud/depth/000613.png',
#  './nyud/depth/000614.png',
#  './nyud/depth/000615.png',
#  './nyud/depth/000616.png',
#  './nyud/depth/000617.png',
#  './nyud/depth/000618.png',
#  './nyud/depth/000619.png',
#  './nyud/depth/000620.png',
#  './nyud/depth/000621.png',
#  './nyud/depth/000622.png',
#  './nyud/depth/000623.png',
#  './nyud/depth/000624.png',
#  './nyud/depth/000625.png',
#  './nyud/depth/000626.png',
#  './nyud/depth/000627.png',
#  './nyud/depth/000628.png',
#  './nyud/depth/000629.png',
#  './nyud/depth/000630.png',
#  './nyud/depth/000631.png',
#  './nyud/depth/000632.png',
#  './nyud/depth/000633.png',
#  './nyud/depth/000634.png',
#  './nyud/depth/000635.png',
#  './nyud/depth/000636.png',
#  './nyud/depth/000637.png',
#  './nyud/depth/000638.png',
#  './nyud/depth/000639.png',
#  './nyud/depth/000640.png',
#  './nyud/depth/000641.png',
#  './nyud/depth/000642.png',
#  './nyud/depth/000643.png',
#  './nyud/depth/000644.png',
#  './nyud/depth/000645.png',
#  './nyud/depth/000646.png',
#  './nyud/depth/000647.png',
#  './nyud/depth/000648.png',
#  './nyud/depth/000649.png',
#  './nyud/depth/000650.png',
#  './nyud/depth/000651.png',
#  './nyud/depth/000652.png',
#  './nyud/depth/000653.png',
#  './nyud/depth/000654.png',
#  './nyud/depth/000655.png',
#  './nyud/depth/000656.png',
#  './nyud/depth/000657.png',
#  './nyud/depth/000658.png',
#  './nyud/depth/000659.png',
#  './nyud/depth/000660.png',
#  './nyud/depth/000661.png',
#  './nyud/depth/000662.png',
#  './nyud/depth/000663.png',
#  './nyud/depth/000664.png',
#  './nyud/depth/000665.png',
#  './nyud/depth/000666.png',
#  './nyud/depth/000667.png',
#  './nyud/depth/000668.png',
#  './nyud/depth/000669.png',
#  './nyud/depth/000670.png',
#  './nyud/depth/000671.png',
#  './nyud/depth/000672.png',
#  './nyud/depth/000673.png',
#  './nyud/depth/000674.png',
#  './nyud/depth/000675.png',
#  './nyud/depth/000676.png',
#  './nyud/depth/000677.png',
#  './nyud/depth/000678.png',
#  './nyud/depth/000679.png',
#  './nyud/depth/000680.png',
#  './nyud/depth/000681.png',
#  './nyud/depth/000682.png',
#  './nyud/depth/000683.png',
#  './nyud/depth/000684.png',
#  './nyud/depth/000685.png',
#  './nyud/depth/000686.png',
#  './nyud/depth/000687.png',
#  './nyud/depth/000688.png',
#  './nyud/depth/000689.png',
#  './nyud/depth/000690.png',
#  './nyud/depth/000691.png',
#  './nyud/depth/000692.png',
#  './nyud/depth/000693.png',
#  './nyud/depth/000694.png',
#  './nyud/depth/000695.png',
#  './nyud/depth/000696.png',
#  './nyud/depth/000697.png',
#  './nyud/depth/000698.png',
#  './nyud/depth/000699.png',
#  './nyud/depth/000700.png',
#  './nyud/depth/000701.png',
#  './nyud/depth/000702.png',
#  './nyud/depth/000703.png',
#  './nyud/depth/000704.png',
#  './nyud/depth/000705.png',
#  './nyud/depth/000706.png',
#  './nyud/depth/000707.png',
#  './nyud/depth/000708.png',
#  './nyud/depth/000709.png',
#  './nyud/depth/000710.png',
#  './nyud/depth/000711.png',
#  './nyud/depth/000712.png',
#  './nyud/depth/000713.png',
#  './nyud/depth/000714.png',
#  './nyud/depth/000715.png',
#  './nyud/depth/000716.png',
#  './nyud/depth/000717.png',
#  './nyud/depth/000718.png',
#  './nyud/depth/000719.png',
#  './nyud/depth/000720.png',
#  './nyud/depth/000721.png',
#  './nyud/depth/000722.png',
#  './nyud/depth/000723.png',
#  './nyud/depth/000724.png',
#  './nyud/depth/000725.png',
#  './nyud/depth/000726.png',
#  './nyud/depth/000727.png',
#  './nyud/depth/000728.png',
#  './nyud/depth/000729.png',
#  './nyud/depth/000730.png',
#  './nyud/depth/000731.png',
#  './nyud/depth/000732.png',
#  './nyud/depth/000733.png',
#  './nyud/depth/000734.png',
#  './nyud/depth/000735.png',
#  './nyud/depth/000736.png',
#  './nyud/depth/000737.png',
#  './nyud/depth/000738.png',
#  './nyud/depth/000739.png',
#  './nyud/depth/000740.png',
#  './nyud/depth/000741.png',
#  './nyud/depth/000742.png',
#  './nyud/depth/000743.png',
#  './nyud/depth/000744.png',
#  './nyud/depth/000745.png',
#  './nyud/depth/000746.png',
#  './nyud/depth/000747.png',
#  './nyud/depth/000748.png',
#  './nyud/depth/000749.png',
#  './nyud/depth/000750.png',
#  './nyud/depth/000751.png',
#  './nyud/depth/000752.png',
#  './nyud/depth/000753.png',
#  './nyud/depth/000754.png',
#  './nyud/depth/000755.png',
#  './nyud/depth/000756.png',
#  './nyud/depth/000757.png',
#  './nyud/depth/000758.png',
#  './nyud/depth/000759.png',
#  './nyud/depth/000760.png',
#  './nyud/depth/000761.png',
#  './nyud/depth/000762.png',
#  './nyud/depth/000763.png',
#  './nyud/depth/000764.png',
#  './nyud/depth/000765.png',
#  './nyud/depth/000766.png',
#  './nyud/depth/000767.png',
#  './nyud/depth/000768.png',
#  './nyud/depth/000769.png',
#  './nyud/depth/000770.png',
#  './nyud/depth/000771.png',
#  './nyud/depth/000772.png',
#  './nyud/depth/000773.png',
#  './nyud/depth/000774.png',
#  './nyud/depth/000775.png',
#  './nyud/depth/000776.png',
#  './nyud/depth/000777.png',
#  './nyud/depth/000778.png',
#  './nyud/depth/000779.png',
#  './nyud/depth/000780.png',
#  './nyud/depth/000781.png',
#  './nyud/depth/000782.png',
#  './nyud/depth/000783.png',
#  './nyud/depth/000784.png',
#  './nyud/depth/000785.png',
#  './nyud/depth/000786.png',
#  './nyud/depth/000787.png',
#  './nyud/depth/000788.png',
#  './nyud/depth/000789.png',
#  './nyud/depth/000790.png',
#  './nyud/depth/000791.png',
#  './nyud/depth/000792.png',
#  './nyud/depth/000793.png',
#  './nyud/depth/000794.png',
#  './nyud/depth/000795.png',
#  './nyud/depth/000796.png',
#  './nyud/depth/000797.png',
#  './nyud/depth/000798.png',
#  './nyud/depth/000799.png',
#  './nyud/depth/000800.png',
#  './nyud/depth/000801.png',
#  './nyud/depth/000802.png',
#  './nyud/depth/000803.png',
#  './nyud/depth/000804.png',
#  './nyud/depth/000805.png',
#  './nyud/depth/000806.png',
#  './nyud/depth/000807.png',
#  './nyud/depth/000808.png',
#  './nyud/depth/000809.png',
#  './nyud/depth/000810.png',
#  './nyud/depth/000811.png',
#  './nyud/depth/000812.png',
#  './nyud/depth/000813.png',
#  './nyud/depth/000814.png',
#  './nyud/depth/000815.png',
#  './nyud/depth/000816.png',
#  './nyud/depth/000817.png',
#  './nyud/depth/000818.png',
#  './nyud/depth/000819.png',
#  './nyud/depth/000820.png',
#  './nyud/depth/000821.png',
#  './nyud/depth/000822.png',
#  './nyud/depth/000823.png',
#  './nyud/depth/000824.png',
#  './nyud/depth/000825.png',
#  './nyud/depth/000826.png',
#  './nyud/depth/000827.png',
#  './nyud/depth/000828.png',
#  './nyud/depth/000829.png',
#  './nyud/depth/000830.png',
#  './nyud/depth/000831.png',
#  './nyud/depth/000832.png',
#  './nyud/depth/000833.png',
#  './nyud/depth/000834.png',
#  './nyud/depth/000835.png',
#  './nyud/depth/000836.png',
#  './nyud/depth/000837.png',
#  './nyud/depth/000838.png',
#  './nyud/depth/000839.png',
#  './nyud/depth/000840.png',
#  './nyud/depth/000841.png',
#  './nyud/depth/000842.png',
#  './nyud/depth/000843.png',
#  './nyud/depth/000844.png',
#  './nyud/depth/000845.png',
#  './nyud/depth/000846.png',
#  './nyud/depth/000847.png',
#  './nyud/depth/000848.png',
#  './nyud/depth/000849.png',
#  './nyud/depth/000850.png',
#  './nyud/depth/000851.png',
#  './nyud/depth/000852.png',
#  './nyud/depth/000853.png',
#  './nyud/depth/000854.png',
#  './nyud/depth/000855.png',
#  './nyud/depth/000856.png',
#  './nyud/depth/000857.png',
#  './nyud/depth/000858.png',
#  './nyud/depth/000859.png',
#  './nyud/depth/000860.png',
#  './nyud/depth/000861.png',
#  './nyud/depth/000862.png',
#  './nyud/depth/000863.png',
#  './nyud/depth/000864.png',
#  './nyud/depth/000865.png',
#  './nyud/depth/000866.png',
#  './nyud/depth/000867.png',
#  './nyud/depth/000868.png',
#  './nyud/depth/000869.png',
#  './nyud/depth/000870.png',
#  './nyud/depth/000871.png',
#  './nyud/depth/000872.png',
#  './nyud/depth/000873.png',
#  './nyud/depth/000874.png',
#  './nyud/depth/000875.png',
#  './nyud/depth/000876.png',
#  './nyud/depth/000877.png',
#  './nyud/depth/000878.png',
#  './nyud/depth/000879.png',
#  './nyud/depth/000880.png',
#  './nyud/depth/000881.png',
#  './nyud/depth/000882.png',
#  './nyud/depth/000883.png',
#  './nyud/depth/000884.png',
#  './nyud/depth/000885.png',
#  './nyud/depth/000886.png',
#  './nyud/depth/000887.png',
#  './nyud/depth/000888.png',
#  './nyud/depth/000889.png',
#  './nyud/depth/000890.png',
#  './nyud/depth/000891.png',
#  './nyud/depth/000892.png',
#  './nyud/depth/000893.png',
#  './nyud/depth/000894.png',
#  './nyud/depth/000895.png',
#  './nyud/depth/000896.png',
#  './nyud/depth/000897.png',
#  './nyud/depth/000898.png',
#  './nyud/depth/000899.png',
#  './nyud/depth/000900.png',
#  './nyud/depth/000901.png',
#  './nyud/depth/000902.png',
#  './nyud/depth/000903.png',
#  './nyud/depth/000904.png',
#  './nyud/depth/000905.png',
#  './nyud/depth/000906.png',
#  './nyud/depth/000907.png',
#  './nyud/depth/000908.png',
#  './nyud/depth/000909.png',
#  './nyud/depth/000910.png',
#  './nyud/depth/000911.png',
#  './nyud/depth/000912.png',
#  './nyud/depth/000913.png',
#  './nyud/depth/000914.png',
#  './nyud/depth/000915.png',
#  './nyud/depth/000916.png',
#  './nyud/depth/000917.png',
#  './nyud/depth/000918.png',
#  './nyud/depth/000919.png',
#  './nyud/depth/000920.png',
#  './nyud/depth/000921.png',
#  './nyud/depth/000922.png',
#  './nyud/depth/000923.png',
#  './nyud/depth/000924.png',
#  './nyud/depth/000925.png',
#  './nyud/depth/000926.png',
#  './nyud/depth/000927.png',
#  './nyud/depth/000928.png',
#  './nyud/depth/000929.png',
#  './nyud/depth/000930.png',
#  './nyud/depth/000931.png',
#  './nyud/depth/000932.png',
#  './nyud/depth/000933.png',
#  './nyud/depth/000934.png',
#  './nyud/depth/000935.png',
#  './nyud/depth/000936.png',
#  './nyud/depth/000937.png',
#  './nyud/depth/000938.png',
#  './nyud/depth/000939.png',
#  './nyud/depth/000940.png',
#  './nyud/depth/000941.png',
#  './nyud/depth/000942.png',
#  './nyud/depth/000943.png',
#  './nyud/depth/000944.png',
#  './nyud/depth/000945.png',
#  './nyud/depth/000946.png',
#  './nyud/depth/000947.png',
#  './nyud/depth/000948.png',
#  './nyud/depth/000949.png',
#  './nyud/depth/000950.png',
#  './nyud/depth/000951.png',
#  './nyud/depth/000952.png',
#  './nyud/depth/000953.png',
#  './nyud/depth/000954.png',
#  './nyud/depth/000955.png',
#  './nyud/depth/000956.png',
#  './nyud/depth/000957.png',
#  './nyud/depth/000958.png',
#  './nyud/depth/000959.png',
#  './nyud/depth/000960.png',
#  './nyud/depth/000961.png',
#  './nyud/depth/000962.png',
#  './nyud/depth/000963.png',
#  './nyud/depth/000964.png',
#  './nyud/depth/000965.png',
#  './nyud/depth/000966.png',
#  './nyud/depth/000967.png',
#  './nyud/depth/000968.png',
#  './nyud/depth/000969.png',
#  './nyud/depth/000970.png',
#  './nyud/depth/000971.png',
#  './nyud/depth/000972.png',
#  './nyud/depth/000973.png',
#  './nyud/depth/000974.png',
#  './nyud/depth/000975.png',
#  './nyud/depth/000976.png',
#  './nyud/depth/000977.png',
#  './nyud/depth/000978.png',
#  './nyud/depth/000979.png',
#  './nyud/depth/000980.png',
#  './nyud/depth/000981.png',
#  './nyud/depth/000982.png',
#  './nyud/depth/000983.png',
#  './nyud/depth/000984.png',
#  './nyud/depth/000985.png',
#  './nyud/depth/000986.png',
#  './nyud/depth/000987.png',
#  './nyud/depth/000988.png',
#  './nyud/depth/000989.png',
#  './nyud/depth/000990.png',
#  './nyud/depth/000991.png',
#  './nyud/depth/000992.png',
#  './nyud/depth/000993.png',
#  './nyud/depth/000994.png',
#  './nyud/depth/000995.png',
#  './nyud/depth/000996.png',
#  './nyud/depth/000997.png',
#  './nyud/depth/000998.png',
#  './nyud/depth/000999.png',
#  './nyud/depth/001000.png',
#  ...]

# %%
print(len(images))
print(len(depth))
print(len(seg))
# Out:
# 1449
# 1449
# 1449

# %% [markdown]
# Since our dataset is a bit "special", we'll need a Color Map to read it.

# %%
CMAP = np.load('cmap_nyud.npy')
print(len(CMAP))
# Out:
# 256

# %%
np.shape(CMAP)
# Out:
# (256, 3)

# %%
CMAP
# Out:
# array([[  0,   0,   0],
#        [128,   0,   0],
#        [  0, 128,   0],
#        [128, 128,   0],
#        [  0,   0, 128],
#        [128,   0, 128],
#        [  0, 128, 128],
#        [128, 128, 128],
#        [ 64,   0,   0],
#        [192,   0,   0],
#        [ 64, 128,   0],
#        [192, 128,   0],
#        [ 64,   0, 128],
#        [192,   0, 128],
#        [ 64, 128, 128],
#        [192, 128, 128],
#        [  0,  64,   0],
#        [128,  64,   0],
#        [  0, 192,   0],
#        [128, 192,   0],
#        [  0,  64, 128],
#        [128,  64, 128],
#        [  0, 192, 128],
#        [128, 192, 128],
#        [ 64,  64,   0],
#        [192,  64,   0],
#        [ 64, 192,   0],
#        [192, 192,   0],
#        [ 64,  64, 128],
#        [192,  64, 128],
#        [ 64, 192, 128],
#        [192, 192, 128],
#        [  0,   0,  64],
#        [128,   0,  64],
#        [  0, 128,  64],
#        [128, 128,  64],
#        [  0,   0, 192],
#        [128,   0, 192],
#        [  0, 128, 192],
#        [128, 128, 192],
#        [ 64,   0,  64],
#        [192,   0,  64],
#        [ 64, 128,  64],
#        [192, 128,  64],
#        [ 64,   0, 192],
#        [192,   0, 192],
#        [ 64, 128, 192],
#        [192, 128, 192],
#        [  0,  64,  64],
#        [128,  64,  64],
#        [  0, 192,  64],
#        [128, 192,  64],
#        [  0,  64, 192],
#        [128,  64, 192],
#        [  0, 192, 192],
#        [128, 192, 192],
#        [ 64,  64,  64],
#        [192,  64,  64],
#        [ 64, 192,  64],
#        [192, 192,  64],
#        [ 64,  64, 192],
#        [192,  64, 192],
#        [ 64, 192, 192],
#        [192, 192, 192],
#        [ 32,   0,   0],
#        [160,   0,   0],
#        [ 32, 128,   0],
#        [160, 128,   0],
#        [ 32,   0, 128],
#        [160,   0, 128],
#        [ 32, 128, 128],
#        [160, 128, 128],
#        [ 96,   0,   0],
#        [224,   0,   0],
#        [ 96, 128,   0],
#        [224, 128,   0],
#        [ 96,   0, 128],
#        [224,   0, 128],
#        [ 96, 128, 128],
#        [224, 128, 128],
#        [ 32,  64,   0],
#        [160,  64,   0],
#        [ 32, 192,   0],
#        [160, 192,   0],
#        [ 32,  64, 128],
#        [160,  64, 128],
#        [ 32, 192, 128],
#        [160, 192, 128],
#        [ 96,  64,   0],
#        [224,  64,   0],
#        [ 96, 192,   0],
#        [224, 192,   0],
#        [ 96,  64, 128],
#        [224,  64, 128],
#        [ 96, 192, 128],
#        [224, 192, 128],
#        [ 32,   0,  64],
#        [160,   0,  64],
#        [ 32, 128,  64],
#        [160, 128,  64],
#        [ 32,   0, 192],
#        [160,   0, 192],
#        [ 32, 128, 192],
#        [160, 128, 192],
#        [ 96,   0,  64],
#        [224,   0,  64],
#        [ 96, 128,  64],
#        [224, 128,  64],
#        [ 96,   0, 192],
#        [224,   0, 192],
#        [ 96, 128, 192],
#        [224, 128, 192],
#        [ 32,  64,  64],
#        [160,  64,  64],
#        [ 32, 192,  64],
#        [160, 192,  64],
#        [ 32,  64, 192],
#        [160,  64, 192],
#        [ 32, 192, 192],
#        [160, 192, 192],
#        [ 96,  64,  64],
#        [224,  64,  64],
#        [ 96, 192,  64],
#        [224, 192,  64],
#        [ 96,  64, 192],
#        [224,  64, 192],
#        [ 96, 192, 192],
#        [224, 192, 192],
#        [  0,  32,   0],
#        [128,  32,   0],
#        [  0, 160,   0],
#        [128, 160,   0],
#        [  0,  32, 128],
#        [128,  32, 128],
#        [  0, 160, 128],
#        [128, 160, 128],
#        [ 64,  32,   0],
#        [192,  32,   0],
#        [ 64, 160,   0],
#        [192, 160,   0],
#        [ 64,  32, 128],
#        [192,  32, 128],
#        [ 64, 160, 128],
#        [192, 160, 128],
#        [  0,  96,   0],
#        [128,  96,   0],
#        [  0, 224,   0],
#        [128, 224,   0],
#        [  0,  96, 128],
#        [128,  96, 128],
#        [  0, 224, 128],
#        [128, 224, 128],
#        [ 64,  96,   0],
#        [192,  96,   0],
#        [ 64, 224,   0],
#        [192, 224,   0],
#        [ 64,  96, 128],
#        [192,  96, 128],
#        [ 64, 224, 128],
#        [192, 224, 128],
#        [  0,  32,  64],
#        [128,  32,  64],
#        [  0, 160,  64],
#        [128, 160,  64],
#        [  0,  32, 192],
#        [128,  32, 192],
#        [  0, 160, 192],
#        [128, 160, 192],
#        [ 64,  32,  64],
#        [192,  32,  64],
#        [ 64, 160,  64],
#        [192, 160,  64],
#        [ 64,  32, 192],
#        [192,  32, 192],
#        [ 64, 160, 192],
#        [192, 160, 192],
#        [  0,  96,  64],
#        [128,  96,  64],
#        [  0, 224,  64],
#        [128, 224,  64],
#        [  0,  96, 192],
#        [128,  96, 192],
#        [  0, 224, 192],
#        [128, 224, 192],
#        [ 64,  96,  64],
#        [192,  96,  64],
#        [ 64, 224,  64],
#        [192, 224,  64],
#        [ 64,  96, 192],
#        [192,  96, 192],
#        [ 64, 224, 192],
#        [192, 224, 192],
#        [ 32,  32,   0],
#        [160,  32,   0],
#        [ 32, 160,   0],
#        [160, 160,   0],
#        [ 32,  32, 128],
#        [160,  32, 128],
#        [ 32, 160, 128],
#        [160, 160, 128],
#        [ 96,  32,   0],
#        [224,  32,   0],
#        [ 96, 160,   0],
#        [224, 160,   0],
#        [ 96,  32, 128],
#        [224,  32, 128],
#        [ 96, 160, 128],
#        [224, 160, 128],
#        [ 32,  96,   0],
#        [160,  96,   0],
#        [ 32, 224,   0],
#        [160, 224,   0],
#        [ 32,  96, 128],
#        [160,  96, 128],
#        [ 32, 224, 128],
#        [160, 224, 128],
#        [ 96,  96,   0],
#        [224,  96,   0],
#        [ 96, 224,   0],
#        [224, 224,   0],
#        [ 96,  96, 128],
#        [224,  96, 128],
#        [ 96, 224, 128],
#        [224, 224, 128],
#        [ 32,  32,  64],
#        [160,  32,  64],
#        [ 32, 160,  64],
#        [160, 160,  64],
#        [ 32,  32, 192],
#        [160,  32, 192],
#        [ 32, 160, 192],
#        [160, 160, 192],
#        [ 96,  32,  64],
#        [224,  32,  64],
#        [ 96, 160,  64],
#        [224, 160,  64],
#        [ 96,  32, 192],
#        [224,  32, 192],
#        [ 96, 160, 192],
#        [224, 160, 192],
#        [ 32,  96,  64],
#        [160,  96,  64],
#        [ 32, 224,  64],
#        [160, 224,  64],
#        [ 32,  96, 192],
#        [160,  96, 192],
#        [ 32, 224, 192],
#        [160, 224, 192],
#        [ 96,  96,  64],
#        [224,  96,  64],
#        [ 96, 224,  64],
#        [224, 224,  64],
#        [ 96,  96, 192],
#        [224,  96, 192],
#        [ 96, 224, 192],
#        [224, 224, 192]], dtype=uint8)

# %%
idx = np.random.randint(0,len(seg))

f, (ax0, ax1, ax2) = plt.subplots(1,3, figsize=(20,40))
ax0.imshow(np.array(Image.open(images[idx])))
ax0.set_title("Original")
ax1.imshow(np.array(Image.open(depth[idx])), cmap="plasma")
ax1.set_title("Depth")
ax2.imshow(CMAP[np.array(Image.open(seg[idx]))])
ax2.set_title("Segmentation")
plt.show()

# %%
print(np.unique(np.array(Image.open(seg[idx]))))
print(len(np.unique(np.array(Image.open(seg[idx])))))
# Out:
# [  0   1   5  10  17  19  36  39 255]
# 9

# %%
np.shape(CMAP[np.array(Image.open(seg[idx]))])
# Out:
# (480, 640, 3)

# %%
np.shape(np.array(Image.open(images[idx])))
# Out:
# (480, 640, 3)

# %% [markdown]
# ## Getting the DataLoader
#
# When training a model, 2 elements are going to be very important (compared to the last workshop):
#
# *   The Dataset
# *   The Training Loop, Loss, etc
#
# We already know how to design the model that does join depth and segmentation, so we only need to know how to train it!

# %%
data_file = "train_list_depth.txt"

with open(data_file, "rb") as f:
    datalist = f.readlines()
datalist = [x.decode("utf-8").strip("\n").split("\t") for x in datalist]

root_dir = "/nyud"
masks_names = ("segm", "depth")

print(datalist[0])
print(datalist[0][0])
# Out:
# ['rgb/000003.png', 'masks/000003.png', 'depth/000003.png']
# rgb/000003.png

# %%
import os
abs_paths = [os.path.join("nyud", rpath) for rpath in datalist[0]]
abs_paths
# Out:
# ['nyud/rgb/000003.png', 'nyud/masks/000003.png', 'nyud/depth/000003.png']

# %%
img_arr = np.array(Image.open(abs_paths[0]))#TODO: Load an RGB Image
img_h, img_w, _ = np.shape(img_arr)

print(f"img_arr.shape = {np.shape(img_arr)}")
plt.imshow(img_arr)
plt.show()
# Out:
# img_arr.shape = (480, 640, 3)

# %%
masks_names = ("segm", "depth")

for mask_name, mask_path in zip(masks_names, abs_paths[1:]):
    mask = np.array(Image.open(mask_path))
    print(f"np.shape(mask) = {np.shape(mask)}")
    plt.imshow(mask)
    plt.show()
# Out:
# np.shape(mask) = (480, 640)
# np.shape(mask) = (480, 640)

# %%
from torch.utils.data import Dataset

class HydranetDataset(Dataset):

    def __init__(self, data_file, transform=None):
        with open(data_file, "rb") as f:
            datalist = f.readlines()
        self.datalist = [x.decode("utf-8").strip("\n").split("\t") for x in datalist]
        self.root_dir = "nyud"
        self.transform = transform
        self.masks_names = ("segm", "depth")

    def __len__(self):
        return len(self.datalist)

    def __getitem__(self, idx):
        abs_paths = [os.path.join(self.root_dir, rpath) for rpath in self.datalist[idx]] # Will output list of nyud/*/00000.png
        sample = {}
        sample["image"] = np.array(Image.open(abs_paths[0]))#TODO: Copy/Paste your loaded code

        for mask_name, mask_path in zip(self.masks_names, abs_paths[1:]):
            sample[f"{mask_name}"] = np.array(Image.open(mask_path))

        if self.transform:
            sample["names"] = self.masks_names
            sample = self.transform(sample)
            # the names key can be removed by the transformation
            if "names" in sample:
                del sample["names"]
        return sample

# %% [markdown]
# ### Normalization — Will be common to all images

# %%
from utils import Normalise, RandomCrop, ToTensor, RandomMirror
import torchvision.transforms as transforms

# %%
img_scale = 1.0 / 255
depth_scale = 5000.0

img_mean = np.array([0.485, 0.456, 0.406])
img_std = np.array([0.229, 0.224, 0.225])

normalise_params = [img_scale, img_mean.reshape((1, 1, 3)), img_std.reshape((1, 1, 3)), depth_scale,]

transform_common = [Normalise(*normalise_params), ToTensor()]

# %% [markdown]
# ### Transforms

# %%
#crop_size = 400
crop_size = min(img_w, img_h)
transform_train = transforms.Compose([RandomMirror(), RandomCrop(crop_size)] + transform_common)
transform_val = transforms.Compose(transform_common)

# %% [markdown]
# ### DataLoader

# %%
train_batch_size = 4
val_batch_size = 4
train_file = "train_list_depth.txt"
val_file = "val_list_depth.txt"

# %%
from torch.utils.data import DataLoader

#TRAIN DATALOADER
trainloader = DataLoader(HydranetDataset(train_file, transform_train),
                          batch_size=train_batch_size,
                          shuffle=True,
                          num_workers=0,
                          pin_memory=True,
                          drop_last=True)#TODO: Call the Train DataLoader

# VALIDATION DATALOADER
valloader = DataLoader(HydranetDataset(val_file, transform_val),
                       batch_size=val_batch_size,
                       shuffle=True,
                       num_workers=0,
                       pin_memory=True,
                       drop_last=False)#TODO: Call the Validation DataLoader

# %% [markdown]
# # 2 — Creating the HydraNet
# We now have 2 DataLoaders: one for training, and one for validation/test. <p>
#
# In the next step, we're going to define our model, following the paper [Real-Time Joint Semantic Segmentation and Depth Estimation Using Asymmetric Annotations](https://arxiv.org/pdf/1809.04766.pdf) —— If you haven't read it yet, now is the time.
# <p>
#
# > ![](https://d3i71xaburhd42.cloudfront.net/435d4b5c30f10753d277848a17baddebd98d3c31/2-Figure1-1.png)
#
# Our model takes an input RGB image, make it go through an encoder, a lightweight refinenet decoder, and then has 2 heads, one for each task.<p>
# Things to note:
# * The only **convolutions** we'll need will be 3x3 and 1x1
# * We also need a **MaxPooling 5x5**
# * **CRP-Blocks** are implemented as Skip-Connection Operations
# * **Each Head is made of a 1x1 convolution followed by a 3x3 convolution**, only the data and the loss change there

# %% [markdown]
# ## Building the Encoder — A MobileNetv2
# ![](https://iq.opengenus.org/content/images/2020/11/conv_mobilenet_v2.jpg)

# %%
def conv3x3(in_channels, out_channels, stride=1, dilation=1, groups=1, bias=False):
    """3x3 Convolution: Depthwise:
    https://pytorch.org/docs/stable/generated/torch.nn.Conv2d.html
    """
    return nn.Conv2d(in_channels, out_channels, kernel_size=3, stride=stride, padding=dilation, dilation=dilation, bias=bias, groups=groups)

# %%
def conv1x1(in_channels, out_channels, stride=1, groups=1, bias=False,):
    "1x1 Convolution: Pointwise"
    return nn.Conv2d(in_channels, out_channels, kernel_size=1, stride=stride, padding=0, bias=bias, groups=groups)

# %%
def batchnorm(num_features):
    """
    https://pytorch.org/docs/stable/generated/torch.nn.BatchNorm2d.html
    """
    return nn.BatchNorm2d(num_features, affine=True, eps=1e-5, momentum=0.1)

# %%
def convbnrelu(in_channels, out_channels, kernel_size, stride=1, groups=1, act=True):
    "conv-batchnorm-relu"
    if act:
        return nn.Sequential(nn.Conv2d(in_channels, out_channels, kernel_size, stride=stride, padding=int(kernel_size / 2.), groups=groups, bias=False),
                             batchnorm(out_channels),
                             nn.ReLU6(inplace=True))
    else:
        return nn.Sequential(nn.Conv2d(in_channels, out_channels, kernel_size, stride=stride, padding=int(kernel_size / 2.), groups=groups, bias=False),
                             batchnorm(out_channels))

# %%
class InvertedResidualBlock(nn.Module):
    """Inverted Residual Block from https://arxiv.org/abs/1801.04381"""
    def __init__(self, in_planes, out_planes, expansion_factor, stride=1):
        super().__init__() # Python 3
        intermed_planes = in_planes * expansion_factor
        self.residual = (in_planes == out_planes) and (stride == 1) # Boolean/Condition
        self.output = nn.Sequential(convbnrelu(in_planes, intermed_planes, 1),
                                    convbnrelu(intermed_planes, intermed_planes, 3, stride=stride, groups=intermed_planes),
                                    convbnrelu(intermed_planes, out_planes, 1, act=False))

    def forward(self, x):
        #residual = x
        out = self.output(x)
        if self.residual:
            return (out + x)#+residual
        else:
            return out

# %%
class MobileNetv2(nn.Module):
    def __init__(self, return_idx=[6]):
        super().__init__()
        # expansion rate, output channels, number of repeats, stride
        self.mobilenet_config = [
        [1, 16, 1, 1],
        [6, 24, 2, 2],
        [6, 32, 3, 2],
        [6, 64, 4, 2],
        [6, 96, 3, 1],
        [6, 160, 3, 2],
        [6, 320, 1, 1],
        ]
        self.in_channels = 32  # number of input channels
        self.num_layers = len(self.mobilenet_config)
        self.layer1 = convbnrelu(3, self.in_channels, kernel_size=3, stride=2)

        self.return_idx = [1, 2, 3, 4, 5, 6]
        #self.return_idx = make_list(return_idx)

        c_layer = 2
        for t, c, n, s in self.mobilenet_config:
            layers = []
            for idx in range(n):
                layers.append(InvertedResidualBlock(self.in_channels,c,expansion_factor=t,stride=s if idx == 0 else 1,))
                self.in_channels = c
            setattr(self, "layer{}".format(c_layer), nn.Sequential(*layers))
            c_layer += 1

        self._out_c = [self.mobilenet_config[idx][1] for idx in self.return_idx] # Output: [24, 32, 64, 96, 160, 320]

    def forward(self, x):
        outs = []
        x = self.layer1(x)
        outs.append(self.layer2(x))  # 16, x / 2
        outs.append(self.layer3(outs[-1]))  # 24, x / 4
        outs.append(self.layer4(outs[-1]))  # 32, x / 8
        outs.append(self.layer5(outs[-1]))  # 64, x / 16
        outs.append(self.layer6(outs[-1]))  # 96, x / 16
        outs.append(self.layer7(outs[-1]))  # 160, x / 32
        outs.append(self.layer8(outs[-1]))  # 320, x / 32
        return [outs[idx] for idx in self.return_idx]

# %%
checkpoint = torch.load("mobilenetv2-e6e8dd43.pth")
print(checkpoint.keys())
# Out:
# /tmp/ipykernel_55386/2523803628.py:1: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load("mobilenetv2-e6e8dd43.pth")
# odict_keys(['layer1.0.weight', 'layer1.1.weight', 'layer1.1.bias', 'layer1.1.running_mean', 'layer1.1.running_var', 'layer1.1.num_batches_tracked', 'layer2.0.output.0.0.weight', 'layer2.0.output.0.1.weight', 'layer2.0.output.0.1.bias', 'layer2.0.output.0.1.running_mean', 'layer2.0.output.0.1.running_var', 'layer2.0.output.0.1.num_batches_tracked', 'layer2.0.output.1.0.weight', 'layer2.0.output.1.1.weight', 'layer2.0.output.1.1.bias', 'layer2.0.output.1.1.running_mean', 'layer2.0.output.1.1.running_var', 'layer2.0.output.1.1.num_batches_tracked', 'layer2.0.output.2.0.weight', 'layer2.0.output.2.1.weight', 'layer2.0.output.2.1.bias', 'layer2.0.output.2.1.running_mean', 'layer2.0.output.2.1.running_var', 'layer2.0.output.2.1.num_batches_tracked', 'layer3.0.output.0.0.weight', 'layer3.0.output.0.1.weight', 'layer3.0.output.0.1.bias', 'layer3.0.output.0.1.running_mean', 'layer3.0.output.0.1.running_var', 'layer3.0.output.0.1.num_batches_tracked', 'layer3.0.output.1.0.weight', 'layer3.0.output.1.1.weight', 'layer3.0.output.1.1.bias', 'layer3.0.output.1.1.running_mean', 'layer3.0.output.1.1.running_var', 'layer3.0.output.1.1.num_batches_tracked', 'layer3.0.output.2.0.weight', 'layer3.0.output.2.1.weight', 'layer3.0.output.2.1.bias', 'layer3.0.output.2.1.running_mean', 'layer3.0.output.2.1.running_var', 'layer3.0.output.2.1.num_batches_tracked', 'layer3.1.output.0.0.weight', 'layer3.1.output.0.1.weight', 'layer3.1.output.0.1.bias', 'layer3.1.output.0.1.running_mean', 'layer3.1.output.0.1.running_var', 'layer3.1.output.0.1.num_batches_tracked', 'layer3.1.output.1.0.weight', 'layer3.1.output.1.1.weight', 'layer3.1.output.1.1.bias', 'layer3.1.output.1.1.running_mean', 'layer3.1.output.1.1.running_var', 'layer3.1.output.1.1.num_batches_tracked', 'layer3.1.output.2.0.weight', 'layer3.1.output.2.1.weight', 'layer3.1.output.2.1.bias', 'layer3.1.output.2.1.running_mean', 'layer3.1.output.2.1.running_var', 'layer3.1.output.2.1.num_batches_tracked', 'layer4.0.output.0.0.weight', 'layer4.0.output.0.1.weight', 'layer4.0.output.0.1.bias', 'layer4.0.output.0.1.running_mean', 'layer4.0.output.0.1.running_var', 'layer4.0.output.0.1.num_batches_tracked', 'layer4.0.output.1.0.weight', 'layer4.0.output.1.1.weight', 'layer4.0.output.1.1.bias', 'layer4.0.output.1.1.running_mean', 'layer4.0.output.1.1.running_var', 'layer4.0.output.1.1.num_batches_tracked', 'layer4.0.output.2.0.weight', 'layer4.0.output.2.1.weight', 'layer4.0.output.2.1.bias', 'layer4.0.output.2.1.running_mean', 'layer4.0.output.2.1.running_var', 'layer4.0.output.2.1.num_batches_tracked', 'layer4.1.output.0.0.weight', 'layer4.1.output.0.1.weight', 'layer4.1.output.0.1.bias', 'layer4.1.output.0.1.running_mean', 'layer4.1.output.0.1.running_var', 'layer4.1.output.0.1.num_batches_tracked', 'layer4.1.output.1.0.weight', 'layer4.1.output.1.1.weight', 'layer4.1.output.1.1.bias', 'layer4.1.output.1.1.running_mean', 'layer4.1.output.1.1.running_var', 'layer4.1.output.1.1.num_batches_tracked', 'layer4.1.output.2.0.weight', 'layer4.1.output.2.1.weight', 'layer4.1.output.2.1.bias', 'layer4.1.output.2.1.running_mean', 'layer4.1.output.2.1.running_var', 'layer4.1.output.2.1.num_batches_tracked', 'layer4.2.output.0.0.weight', 'layer4.2.output.0.1.weight', 'layer4.2.output.0.1.bias', 'layer4.2.output.0.1.running_mean', 'layer4.2.output.0.1.running_var', 'layer4.2.output.0.1.num_batches_tracked', 'layer4.2.output.1.0.weight', 'layer4.2.output.1.1.weight', 'layer4.2.output.1.1.bias', 'layer4.2.output.1.1.running_mean', 'layer4.2.output.1.1.running_var', 'layer4.2.output.1.1.num_batches_tracked', 'layer4.2.output.2.0.weight', 'layer4.2.output.2.1.weight', 'layer4.2.output.2.1.bias', 'layer4.2.output.2.1.running_mean', 'layer4.2.output.2.1.running_var', 'layer4.2.output.2.1.num_batches_tracked', 'layer5.0.output.0.0.weight', 'layer5.0.output.0.1.weight', 'layer5.0.output.0.1.bias', 'layer5.0.output.0.1.running_mean', 'layer5.0.output.0.1.running_var', 'layer5.0.output.0.1.num_batches_tracked', 'layer5.0.outp ...

# %%
encoder = MobileNetv2()
encoder.load_state_dict(torch.load("mobilenetv2-e6e8dd43.pth"))
# Out:
# /tmp/ipykernel_55386/4003048153.py:2: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   encoder.load_state_dict(torch.load("mobilenetv2-e6e8dd43.pth"))
# <All keys matched successfully>

# %%
print(encoder)
# Out:
# MobileNetv2(
#   (layer1): Sequential(
#     (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU6(inplace=True)
#   )
#   (layer2): Sequential(
#     (0): InvertedResidualBlock(
#       (output): Sequential(
#         (0): Sequential(
#           (0): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): Sequential(
#           (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#           (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Sequential(
#           (0): Conv2d(32, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#     )
#   )
#   (layer3): Sequential(
#     (0): InvertedResidualBlock(
#       (output): Sequential(
#         (0): Sequential(
#           (0): Conv2d(16, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): Sequential(
#           (0): Conv2d(96, 96, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=96, bias=False)
#           (1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Sequential(
#           (0): Conv2d(96, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (1): InvertedResidualBlock(
#       (output): Sequential(
#         (0): Sequential(
#           (0): Conv2d(24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): Sequential(
#           (0): Conv2d(144, 144, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=144, bias=False)
#           (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Sequential(
#           (0): Conv2d(144, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#     )
#   )
#   (layer4): Sequential(
#     (0): InvertedResidualBlock(
#       (output): Sequential(
#         (0): Sequential(
#           (0): Conv2d(24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): Sequential(
#           (0): Conv2d(144, 144, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=144, bias=False)
#           (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Sequential(
#           (0): Conv2d(144, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (1): InvertedResidualBlock(
#       (output): Sequential(
#         (0): Sequential(
#           (0): Conv2d(32, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): Sequential(
#           (0): Conv2d(192, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=192, bias=False)
#           (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Sequential(
#           (0): Conv2d(192, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (2): InvertedResidualBlock(
#       (output): Sequential(
#         (0): Sequential(
#           (0): Conv2d(32, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): Sequential(
#           (0): Conv2d(192, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=192, bias=False)
#           (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Sequential(
#           (0): Conv2d(192, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#     )
#   )
#   (layer5): Sequential(
#     (0): InvertedResidualBlock(
#       (output): Sequential(
#         (0): Sequential(
#           (0): Conv2d(32, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): Sequential(
#           (0): Conv2d(192, 192, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=192, bias=False)
#           (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Sequential(
#           (0): Conv2d(192, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (1): InvertedResidualBlock(
#       (output): Sequential(
#         (0): Sequential(
#           (0): Conv2d(64, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): Sequential(
#           (0): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384, bias=False)
#           (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Sequential(
#           (0): Conv2d(384, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (2): InvertedResidualBlock(
#       (output): Sequential(
#         (0): Sequential(
#           (0): Conv2d(64, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): Sequential(
#           (0): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384, bias=False)
#           (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Sequential(
#           (0): Conv2d(384, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (3): InvertedResidualBlock(
#       (output): Sequential(
#         (0): Sequential(
#           (0): Conv2d(64, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): Sequential(
#           (0): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384, bias=False)
#           (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Sequential(
#           (0): Conv2d(384, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#     )
#   )
#   (layer6): Sequential(
#     (0): InvertedResidualBlock(
#       (output): Sequential(
#         (0): Sequential(
#           (0): Conv2d(64, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): Sequential(
#           (0): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384, bias=False)
#           (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Sequential(
#           (0): Conv2d(384, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (1): InvertedResidualBlock(
#       (output): Sequential(
#         (0): Sequential(
#           (0): Conv2d(96, 576, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): Sequential(
#           (0): Conv2d(576, 576, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=576, bias=False)
#           (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Sequential(
#           (0): Conv2d(576, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (2): InvertedResidualBlock(
#       (output): Sequential(
#         (0): Sequential(
#           (0): Conv2d(96, 576, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): Sequential(
#           (0): Conv2d(576, 576, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=576, bias=False)
#           (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Sequential(
#           (0): Conv2d(576, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#     )
#   )
#   (layer7): Sequential(
#     (0): InvertedResidualBlock(
#       (output): Sequential(
#         (0): Sequential(
#           (0): Conv2d(96, 576, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): Sequential(
#           (0): Conv2d(576, 576, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=576, bias=False)
#           (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Sequential(
#           (0): Conv2d(576, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (1): InvertedResidualBlock(
#       (output): Sequential(
#         (0): Sequential(
#           (0): Conv2d(160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): Sequential(
#           (0): Conv2d(960, 960, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=960, bias=False)
#           (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Sequential(
#           (0): Conv2d(960, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (2): InvertedResidualBlock(
#       (output): Sequential(
#         (0): Sequential(
#           (0): Conv2d(160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): Sequential(
#           (0): Conv2d(960, 960, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=960, bias=False)
#           (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Sequential(
#           (0): Conv2d(960, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#     )
#   )
#   (layer8): Sequential(
#     (0): InvertedResidualBlock(
#       (output): Sequential(
#         (0): Sequential(
#           (0): Conv2d(160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): Sequential(
#           (0): Conv2d(960, 960, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=960, bias=False)
#           (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Sequential(
#           (0): Conv2d(960, 320, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#     )
#   )
# )

# %% [markdown]
# ## Building the Decoder - A Multi-Task Lighweight RefineNet
# Paper: https://arxiv.org/pdf/1810.03272.pdf
# ![](https://drsleep.github.io/images/rf_arch.png)

# %%
def make_list(x):
    """Returns the given input as a list."""
    if isinstance(x, list):
        return x
    elif isinstance(x, tuple):
        return list(x)
    else:
        return [x]

# %%
class CRPBlock(nn.Module):
    """CRP definition"""
    def __init__(self, in_planes, out_planes, n_stages, groups=False):
        super().__init__()
        for i in range(n_stages):
            if groups:
                setattr(self, '{}_{}'.format(i + 1, 'outvar_dimred'),
                    conv1x1(in_planes if (i == 0) else out_planes,
                            out_planes, stride=1,
                            bias=False, groups= in_planes if i==0 else out_planes))
            else:
                setattr(self, '{}_{}'.format(i + 1, 'outvar_dimred'),
                    conv1x1(in_planes if (i == 0) else out_planes,
                            out_planes, stride=1,
                            bias=False, groups=1))

        self.stride = 1
        self.n_stages = n_stages
        self.maxpool = nn.MaxPool2d(kernel_size=5, stride=1, padding=2)

    def forward(self, x):
        top = x
        for i in range(self.n_stages):
            top = self.maxpool(top)
            top = getattr(self, '{}_{}'.format(i + 1, 'outvar_dimred'))(top)
            x = top + x
        return x

# %%
class MTLWRefineNet(nn.Module):
    def __init__(self, input_sizes, num_classes, agg_size=256, n_crp=4):
        super().__init__()

        stem_convs = nn.ModuleList()
        crp_blocks = nn.ModuleList()
        adapt_convs = nn.ModuleList()
        heads = nn.ModuleList()

        # Reverse since we recover information from the end
        input_sizes = list(reversed((input_sizes)))

        # No reverse for collapse indices is needed
        self.collapse_ind = [[0, 1], [2, 3], 4, 5]

        groups = [False] * len(self.collapse_ind)
        groups[-1] = True

        for size in input_sizes:
            stem_convs.append(conv1x1(size, agg_size, bias=False))

        for group in groups:
            crp_blocks.append(self._make_crp(agg_size, agg_size, n_crp, group))
            adapt_convs.append(conv1x1(agg_size, agg_size, bias=False))

        self.stem_convs = stem_convs
        self.crp_blocks = crp_blocks
        self.adapt_convs = adapt_convs[:-1]

        num_classes = list(num_classes)
        for n_out in num_classes:
            heads.append(
                nn.Sequential(
                    conv1x1(agg_size, agg_size, groups=agg_size, bias=False),
                    nn.ReLU6(inplace=False),
                    conv3x3(agg_size, n_out, bias=True),
                )
            )

        self.heads = heads
        self.relu = nn.ReLU6(inplace=True)

    def forward(self, xs):
        xs = list(reversed(xs))
        for idx, (conv, x) in enumerate(zip(self.stem_convs, xs)):
            xs[idx] = conv(x)

        # Collapse layers
        c_xs = [sum([xs[idx] for idx in make_list(c_idx)]) for c_idx in self.collapse_ind ]

        for idx, (crp, x) in enumerate(zip(self.crp_blocks, c_xs)):
            if idx == 0:
                y = self.relu(x)
            else:
                y = self.relu(x + y)
            y = crp(y)
            if idx < (len(c_xs) - 1):
                y = self.adapt_convs[idx](y)
                y = F.interpolate(
                    y,
                    size=c_xs[idx + 1].size()[2:],
                    mode="bilinear",
                    align_corners=True,
                )

        outs = []
        for head in self.heads:
            outs.append(head(y))
        return outs

    @staticmethod
    def _make_crp(in_planes, out_planes, stages, groups):
        # Same as previous, but showing the use of a @staticmethod
        layers = [CRPBlock(in_planes, out_planes, stages, groups)]
        return nn.Sequential(*layers)

# %%
num_classes = (40, 1)
decoder = MTLWRefineNet(encoder._out_c, num_classes)
print(decoder)
# Out:
# MTLWRefineNet(
#   (stem_convs): ModuleList(
#     (0): Conv2d(320, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (1): Conv2d(160, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (2): Conv2d(96, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (4): Conv2d(32, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (5): Conv2d(24, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   )
#   (crp_blocks): ModuleList(
#     (0-2): 3 x Sequential(
#       (0): CRPBlock(
#         (1_outvar_dimred): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (2_outvar_dimred): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3_outvar_dimred): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (4_outvar_dimred): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (maxpool): MaxPool2d(kernel_size=5, stride=1, padding=2, dilation=1, ceil_mode=False)
#       )
#     )
#     (3): Sequential(
#       (0): CRPBlock(
#         (1_outvar_dimred): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), groups=256, bias=False)
#         (2_outvar_dimred): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), groups=256, bias=False)
#         (3_outvar_dimred): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), groups=256, bias=False)
#         (4_outvar_dimred): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), groups=256, bias=False)
#         (maxpool): MaxPool2d(kernel_size=5, stride=1, padding=2, dilation=1, ceil_mode=False)
#       )
#     )
#   )
#   (adapt_convs): ModuleList(
#     (0-2): 3 x Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   )
#   (heads): ModuleList(
#     (0): Sequential(
#       (0): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), groups=256, bias=False)
#       (1): ReLU6()
#       (2): Conv2d(256, 40, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     )
#     (1): Sequential(
#       (0): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), groups=256, bias=False)
#       (1): ReLU6()
#       (2): Conv2d(256, 1, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     )
#   )
#   (relu): ReLU6(inplace=True)
# )

# %% [markdown]
# # 3 — Train the Model
#
# Now that we've define our encoder and decoder. We are ready to train our model on the NYUDv2 Dataset.
#
# Here's what we'll need:
#
# *   Functions like **train() and valid()**
# *   **An Optimizer and a Loss Function**
# *   **Hyperparameters** such as Weight Decay, Momentum, Learning Rate, Epochs, ...
#
# Doesn't sound so bad, does it?

# %% [markdown]
# ## Loss Function
#
# Let's begin with the Loss and Optimization we'll need.
#
# * The **Segmentation Loss** is the **Cross Entropy Loss**, working as a per-pixel classification function with 15 or so classes.
#
# * The **Depth Loss** will be the **Inverse Huber Loss**.

# %%
from utils import InvHuberLoss

ignore_index = 255
ignore_depth = 0

crit_segm = nn.CrossEntropyLoss(ignore_index=ignore_index)#TODO: Define the Loss for Segmentation
crit_depth = InvHuberLoss(ignore_index=ignore_depth) #TODO: Define the Loss for Depth

# %% [markdown]
# ## Optimizer
# For the optimizer, we'll use the **Stochastic Gradient Descent** or **Adam**. We'll also add techniques such as weight decay or momentum.

# %%
lr_encoder = 1e-2
lr_decoder = 1e-3
betas_encoder = (0.9, 0.99)
betas_decoder = (0.9, 0.999)
#momentum_encoder = 0.9
#momentum_decoder = 0.9
weight_decay_encoder = 1e-5
weight_decay_decoder = 1e-5

# %%
'''SGD'''
'''
optims = [torch.optim.SGD(encoder.parameters(), lr=lr_encoder, momentum=momentum_encoder, weight_decay=weight_decay_encoder),
         torch.optim.SGD(decoder.parameters(), lr=lr_decoder, momentum=momentum_decoder, weight_decay=weight_decay_decoder)]
'''
     
'''Adam'''
optims = [torch.optim.Adam(encoder.parameters(), lr=lr_encoder, betas=betas_encoder, weight_decay=weight_decay_encoder),
          torch.optim.Adam(decoder.parameters(), lr=lr_decoder, betas=betas_decoder, weight_decay=weight_decay_decoder)]
#TODO: Create a List of 2 Optimizers: One for the encoder, one for the decoder

# %% [markdown]
# ## Model Definition & State Loading

# %%
n_epochs = 1000

# %%
from model_helpers import Saver, load_state_dict
import operator
import json
import logging

init_vals = (0.0, 10000.0)
comp_fns = [operator.gt, operator.lt]
ckpt_dir = "./"
ckpt_path = "./checkpoint.pth.tar"

saver = Saver(
    args=locals(),
    ckpt_dir=ckpt_dir,
    best_val=init_vals,
    condition=comp_fns,
    save_several_mode=all,
)

# %%
hydranet = nn.DataParallel(nn.Sequential(encoder, decoder).cuda()) # Use .cpu() if you prefer a slow death

print("Model has {} parameters".format(sum([p.numel() for p in hydranet.parameters()])))

start_epoch, _, state_dict = saver.maybe_load(ckpt_path=ckpt_path, keys_to_load=["epoch", "best_val", "state_dict"],)
load_state_dict(hydranet, state_dict)

if start_epoch is None:
    start_epoch = 0
# Out:
# Model has 3070057 parameters

# %%
print(f"state_dict = {state_dict}")
# Out:
# state_dict = None

# %%
print(start_epoch)
# Out:
# 0

# %% [markdown]
# ## Learning Rate Scheduler

# %%
'''Normal learning rate scheduler'''
opt_scheds = []
for opt in optims:
    opt_scheds.append(torch.optim.lr_scheduler.MultiStepLR(opt, np.arange(start_epoch + 100, n_epochs, 100), gamma=0.1))

'''Cosine Annealing learning rate scheduler'''
'''
opt_scheds = []
for opt in optims:
    opt_scheds.append(torch.optim.lr_scheduler.CosineAnnealingLR(opt, T_max=n_epochs))
'''
# Out:
# '\nopt_scheds = []\nfor opt in optims:\n    opt_scheds.append(torch.optim.lr_scheduler.CosineAnnealingLR(opt, T_max=n_epochs))\n'

# %% [markdown]
# ## Training and Validation Loops
#
# Now, all we need to do is go through the Train and Validation DataLoaders, and train our model.
#
# It should look like this:
# ```python
# for i in range(start_epoch, n_epochs):
#     for sched in opt_scheds:
#         sched.step(i)
#     hydranet.train() # Set to train mode
#     train(...) # Call the train function
#
#     if i % val_every == 0:
#         model1.eval() # Set to Eval Mode
#         with torch.no_grad():
#             vals = validate(...) # Call the validate function
# ```
#
# In the (...), we'll send our dataloader, loss functions, optimizers, and everything we've defined before.<p>
#
# Which means **we need a training and validate functions.**

# %%
from utils import AverageMeter
from tqdm import tqdm

# %%
def train(model, opts, crits, dataloader, loss_coeffs=(1.0,), grad_norm=0.0):
    model.train()

    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    loss_meter = AverageMeter()
    pbar = tqdm(dataloader)

    for sample in pbar:
        loss = 0.0
        input = sample["image"].float().to(device)
        targets = [sample[k].to(device) for k in dataloader.dataset.masks_names]

        #print(f"input.shape = {input.shape}")
        #print(f"targets[0].shape = {targets[0].shape}")
        #print(f"targets[1].shape = {targets[1].shape}")

        #FORWARD
        outputs = model(input)#TODO: Run a Forward pass
        #print(f"outputs[0].shape = {outputs[0].shape}")
        #print(f"outputs[1].shape = {outputs[1].shape}")

        for out, target, crit, loss_coeff in zip(outputs, targets, crits, loss_coeffs):
            loss += loss_coeff * crit(
                F.interpolate(
                    out, size=target.size()[1:], mode="bilinear", align_corners=False
                ).squeeze(dim=1),
                target.squeeze(dim=1),
            )

        # BACKWARD
        #TODO: Zero Out the Gradients
        for opt in opts:
            opt.zero_grad()
        #TODO: Call Loss.Backward
        loss.backward()

        if grad_norm > 0.0:
            torch.nn.utils.clip_grad_norm_(model.parameters(), grad_norm)
        #TODO: Run one step
        for opt in opts:
            opt.step()

        loss_meter.update(loss.item())
        pbar.set_description(
            "Loss {:.3f} | Avg. Loss {:.3f}".format(loss.item(), loss_meter.avg)
        )

# %%
def validate(model, metrics, dataloader):
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model.eval()
    for metric in metrics:
        metric.reset()

    pbar = tqdm(dataloader)

    def get_val(metrics):
        results = [(m.name, m.val()) for m in metrics]
        names, vals = list(zip(*results))
        out = ["{} : {:4f}".format(name, val) for name, val in results]
        return vals, " | ".join(out)

    with torch.no_grad():
        for sample in pbar:
            # Get the Data
            input = sample["image"].float().to(device)
            targets = [sample[k].to(device) for k in dataloader.dataset.masks_names]

            #input, targets = get_input_and_targets(sample=sample, dataloader=dataloader, device=device)
            targets = [target.squeeze(dim=1).cpu().numpy() for target in targets]

            # Forward
            outputs = model(input)
            #outputs = make_list(outputs)

            # Backward
            for out, target, metric in zip(outputs, targets, metrics):
                metric.update(
                    F.interpolate(out, size=target.shape[1:], mode="bilinear", align_corners=False)
                    .squeeze(dim=1)
                    .cpu()
                    .numpy(),
                    target,
                )
            pbar.set_description(get_val(metrics)[1])
    vals, _ = get_val(metrics)
    print("----" * 5)
    return vals

# %% [markdown]
# ## Main Loop

# %%
from utils import MeanIoU, RMSE

crop_size = 400
train_batch_size = 16
val_batch_size = 16
val_every = 10
loss_coeffs = (0.5, 0.5)

for i in range(start_epoch, n_epochs+1):
    for sched in opt_scheds:
        sched.step(i)
    
    print(f"Epoch {i}")
    train(model=hydranet, opts=optims, crits=[crit_segm, crit_depth], dataloader=trainloader, loss_coeffs=loss_coeffs, grad_norm=0.0)

    if i%val_every == 0:
        metrics = [MeanIoU(num_classes[0]), RMSE(ignore_val=ignore_depth)]

        with torch.no_grad():
            vals = validate(model=hydranet, metrics=metrics, dataloader=valloader)

        saver.maybe_save(new_val=vals, dict_to_save={"state_dict": hydranet.state_dict(), "epoch": i})
# Out:
# Epoch 125
# Loss 0.604 | Avg. Loss 0.520: 100%|██████████| 49/49 [05:44<00:00,  7.03s/it]
# Epoch 126
# Loss 0.539 | Avg. Loss 0.471: 100%|██████████| 49/49 [04:12<00:00,  5.15s/it]
# Epoch 127
# Loss 0.540 | Avg. Loss 0.503: 100%|██████████| 49/49 [03:21<00:00,  4.11s/it]
# Epoch 128
# Loss 0.563 | Avg. Loss 0.501: 100%|██████████| 49/49 [04:11<00:00,  5.14s/it]
# Epoch 129
# Loss 0.561 | Avg. Loss 0.532: 100%|██████████| 49/49 [02:43<00:00,  3.33s/it]
# Epoch 130
# Loss 0.515 | Avg. Loss 0.590: 100%|██████████| 49/49 [02:26<00:00,  2.99s/it]
# meaniou : 0.203306 | rmse : 0.811119: 100%|██████████| 41/41 [05:32<00:00,  8.11s/it]
# --------------------
# Epoch 131
# Loss 0.518 | Avg. Loss 0.494: 100%|██████████| 49/49 [05:45<00:00,  7.05s/it]
# Epoch 132
# Loss 0.493 | Avg. Loss 0.526: 100%|██████████| 49/49 [05:02<00:00,  6.17s/it]
# Epoch 133
# Loss 0.432 | Avg. Loss 0.497: 100%|██████████| 49/49 [03:00<00:00,  3.68s/it]
# Epoch 134
# Loss 0.546 | Avg. Loss 0.462: 100%|██████████| 49/49 [04:54<00:00,  6.00s/it]
# Epoch 135
# Loss 0.464 | Avg. Loss 0.512: 100%|██████████| 49/49 [03:52<00:00,  4.75s/it]
# Epoch 136
# Loss 0.440 | Avg. Loss 0.522: 100%|██████████| 49/49 [03:28<00:00,  4.25s/it]
# Epoch 137
# Loss 0.543 | Avg. Loss 0.475: 100%|██████████| 49/49 [04:16<00:00,  5.24s/it]
# Epoch 138
# Loss 0.486 | Avg. Loss 0.503: 100%|██████████| 49/49 [04:22<00:00,  5.37s/it]
# Epoch 139
# Loss 0.499 | Avg. Loss 0.523: 100%|██████████| 49/49 [03:12<00:00,  3.92s/it]
# Epoch 140
# Loss 0.573 | Avg. Loss 0.485: 100%|██████████| 49/49 [02:28<00:00,  3.03s/it]
# meaniou : 0.203848 | rmse : 0.809067: 100%|██████████| 41/41 [14:12<00:00, 20.80s/it]
# --------------------
# Epoch 141
# Loss 0.525 | Avg. Loss 0.476: 100%|██████████| 49/49 [30:36<00:00, 37.49s/it]
# Epoch 142
# Loss 0.493 | Avg. Loss 0.447: 100%|██████████| 49/49 [33:04<00:00, 40.49s/it]
# Epoch 143
# Loss 0.487 | Avg. Loss 0.600: 100%|██████████| 49/49 [25:58<00:00, 31.80s/it]
# Epoch 144
# Loss 0.569 | Avg. Loss 0.474: 100%|██████████| 49/49 [22:41<00:00, 27.79s/it]
# Epoch 145
# Loss 0.518 | Avg. Loss 0.479: 100%|██████████| 49/49 [13:12<00:00, 16.18s/it]
# Epoch 146
# Loss 0.483 | Avg. Loss 0.462:  55%|█████▌    | 27/49 [00:45<00:37,  1.70s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[166], line 14
#      11     sched.step(i)
#      13 print(f"Epoch {i}")
# ---> 14 train(model=hydranet, opts=optims, crits=[crit_segm, crit_depth], dataloader=trainloader, loss_coeffs=loss_coeffs, grad_norm=0.0)
#      16 if i%val_every == 0:
#      17     metrics = [MeanIoU(num_classes[0]), RMSE(ignore_val=ignore_depth)]
#
# Cell In[164], line 8, in train(model, opts, crits, dataloader, loss_coeffs, grad_norm)
#       5 loss_meter = AverageMeter()
#       6 pbar = tqdm(dataloader)
# ----> 8 for sample in pbar:
#       9     loss = 0.0
#      10     input = sample["image"].float().to(device)
#
# File ~/miniconda3/envs/mlt_venv/lib/python3.10/site-packages/tqdm/std.py:1181, in tqdm.__iter__(self)
#    1178 time = self._time
#    1180 try:
# -> 1181     for obj in iterable:
#    1182         yield obj
#    1183         # Update and possibly print the progressbar.
#    1184         # Note: does not call self.update(1) for speed optimisation.
#
# File ~/miniconda3/envs/mlt_venv/lib/python3.10/site-packages/torch/utils/data/dataloader.py:630, in _BaseDataLoaderIter.__next__(self)
#     627 if self._sampler_iter is None:
#     628     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     629     self._reset()  # type: ignore[call-arg]
# --> 630 data = self._next_data()
#     631 self._num_yielded += 1
#     632 if self._dataset_kind == _DatasetKind.Iterable and \
#     633         self._IterableDataset_len_called is not None and \
#     634         self._num_yielded > self._IterableDataset_len_called:
#
# File ~/miniconda3/envs/mlt_venv/lib/python3.10/site-packages/torch/utils/data/dataloader.py:673, in _SingleProcessDataLoaderIter._next_data(self)
#     671 def _next_data(self):
#     672     index = self._next_index()  # may raise StopIteration
# --> 673     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     674     if self._pin_memory:
#     675         data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# File ~/miniconda3/envs/mlt_venv/lib/python3.10/site-packages/torch/utils/data/_utils/fetch.py:52, in _MapDatasetFetcher.fetch(self, possibly_batched_index)
#      50         data = self.dataset.__getitems__(possibly_batched_index)
#      51     else:
# ---> 52         data = [self.dataset[idx] for idx in possibly_batched_index]
#      53 else:
#      54     data = self.dataset[possibly_batched_index]
#
# File ~/miniconda3/envs/mlt_venv/lib/python3.10/site-packages/torch/utils/data/_utils/fetch.py:52, in <listcomp>(.0)
#      50         data = self.dataset.__getitems__(possibly_batched_index)
#      51     else:
# ---> 52         data = [self.dataset[idx] for idx in possibly_batched_index]
#      53 else:
#      54     data = self.dataset[possibly_batched_index]
#
# Cell In[29], line 22, in HydranetDataset.__getitem__(self, idx)
#      19 sample["image"] = np.array(Image.open(abs_paths[0]))#TODO: Copy/Paste your loaded code
#      21 for mask_name, mask_path in zip(self.masks_names, abs_paths[1:]):
# ---> 22     sample[f"{mask_name}"] = np.array(Image.open(mask_path))
#      24 if self.transform:
#      25     sample["names"] = self.masks_names
#
# File ~/miniconda3/envs/mlt_venv/lib/python3.10/site-packages/PIL/Image.py:756, in Image.__array_interface__(self)
#     754     new["data"] = self.tobytes("raw", "L")
#     755 else:
# --> 756     new["data"] = self.tobytes()
#     757 new["shape"], new["typestr"] = _conv_type_shape(self)
#     758 return new
#
# File ~/miniconda3/envs/mlt_venv/lib/python3.10/site-packages/PIL/Image.py:805, in Image.tobytes(self, encoder_name, *args)
#     802 if encoder_name == "raw" and encoder_args == ():
#     803     encoder_args = self.mode
# --> 805 self.load()
#     807 if self.width == 0 or self.height == 0:
#     808     return b""
#
# File ~/miniconda3/envs/mlt_venv/lib/python3.10/site-packages/PIL/ImageFile.py:300, in ImageFile.load(self)
#     297         raise OSError(msg)
#     299 b = b + s
# --> 300 n, err_code = decoder.decode(b)
#     301 if n < 0:
#     302     break
#
# KeyboardInterrupt:

# %% [markdown]
# # Inference Challenge
#
# Now that your model is trained and checkpoint saved, try and **load an image from the test dataset and run your model on it**. Print the FPS.
# <p>
#
# **MEGA POINTS** — Load a video, and **implement a video pipeline** as we did on the previous workshop!

# %%
#Good Luck! If you have any good result, send it to jeremy@thinkautonomous.ai directly!
